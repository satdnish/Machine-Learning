# %% [markdown]
# # Linear Regression single variable

# %%
import pandas as pd

# %%
dt=pd.read_csv(r'/home/satdev/Desktop/jupter notebook 1/Insurance_1.csv')

# %%
dt
# Out:
#    age  premium
# 0   25    18000
# 1   30    32000
# 2   35    40000
# 3   40    47000
# 4   45    55000

# %%
import seaborn as sns

# %%
sns.lmplot(x='age',y='premium',data=dt)

# %%
from sklearn import linear_model

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(dt[['age']],dt['premium'])
# Out:
# LinearRegression()

# %%
reg.predict([[26]])
# Out:
# /home/satdev/.local/lib/python3.9/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([22380.])

# %%
reg.coef_
# Out:
# array([1780.])

# %%
reg.intercept_
# Out:
# -23900.000000000015
