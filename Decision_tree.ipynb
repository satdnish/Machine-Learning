# %%
import pandas as pd

# %%
data=pd.read_csv(r'/home/windows/Downloads/csv datasets/tennis.csv')

# %%
data
# Out:
#     day   outlook  temp humidity    wind play
# 0    D1     Sunny   Hot     High    Weak   No
# 1    D2     Sunny   Hot     High  Strong   No
# 2    D3  Overcast   Hot     High    Weak  Yes
# 3    D4      Rain  Mild     High    Weak  Yes
# 4    D5      Rain  Cool   Normal    Weak  Yes
# 5    D6      Rain  Cool   Normal  Strong   No
# 6    D7  Overcast  Cool   Normal  Strong  Yes
# 7    D8     Sunny  Mild     High    Weak   No
# 8    D9     Sunny  Cool   Normal    Weak  Yes
# 9   D10      Rain  Mild   Normal    Weak  Yes
# 10  D11     Sunny  Mild   Normal  Strong  Yes
# 11  D12  Overcast  Mild     High  Strong  Yes
# 12  D13  Overcast   Hot   Normal    Weak  Yes
# 13  D14      Rain  Mild     High  Strong   No

# %%
data=pd.read_csv(r'/home/windows/Downloads/csv datasets/tennis.csv',usecols=['outlook','humidity','wind','play'])

# %%
data
# Out:
#     outlook  humidity  wind  play
# 0         2         0     1     0
# 1         2         0     0     0
# 2         0         0     1     1
# 3         1         0     1     1
# 4         1         1     1     1
# 5         1         1     0     0
# 6         0         1     0     1
# 7         2         0     1     0
# 8         2         1     1     1
# 9         1         1     1     1
# 10        2         1     0     1
# 11        0         0     0     1
# 12        0         1     1     1
# 13        1         0     0     0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
outlook= LabelEncoder()
humidity= LabelEncoder()
wind= LabelEncoder()
play= LabelEncoder()

# %%
data['outlook']=outlook.fit_transform(dt['outlook'])
data['humidity']=outlook.fit_transform(dt['humidity'])
data['wind']=outlook.fit_transform(dt['wind'])
data['play']=outlook.fit_transform(dt['play'])

# %%
data
# Out:
#     outlook  humidity  wind  play
# 0         2         0     1     0
# 1         2         0     0     0
# 2         0         0     1     1
# 3         1         0     1     1
# 4         1         1     1     1
# 5         1         1     0     0
# 6         0         1     0     1
# 7         2         0     1     0
# 8         2         1     1     1
# 9         1         1     1     1
# 10        2         1     0     1
# 11        0         0     0     1
# 12        0         1     1     1
# 13        1         0     0     0

# %%
features_column=['outlook', 'humidity', 'wind']
x=data[features_column]
y=data.play

# %%
x
# Out:
#     outlook  humidity  wind
# 0         2         0     1
# 1         2         0     0
# 2         0         0     1
# 3         1         0     1
# 4         1         1     1
# 5         1         1     0
# 6         0         1     0
# 7         2         0     1
# 8         2         1     1
# 9         1         1     1
# 10        2         1     0
# 11        0         0     0
# 12        0         1     1
# 13        1         0     0

# %%
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     1
# 4     1
# 5     0
# 6     1
# 7     0
# 8     1
# 9     1
# 10    1
# 11    1
# 12    1
# 13    0
# Name: play, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier=DecisionTreeClassifier(criterion='gini')

# %%
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
classifier.predict(x_test)
# Out:
# array([1, 0, 0])

# %%
x_test
# Out:
#    outlook  humidity  wind
# 4        1         1     1
# 0        2         0     1
# 3        1         0     1

# %%
classifier.score(x_test,y_test)
# Out:
# 0.6666666666666666

# %%
from sklearn import tree

# %%
tree.plot_tree(classifier)
# Out:
# [Text(0.3333333333333333, 0.9, 'x[0] <= 0.5\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.16666666666666666, 0.7, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.5, 0.7, 'x[1] <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.3333333333333333, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6666666666666666, 0.5, 'x[0] <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.5, 0.3, 'x[2] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3333333333333333, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6666666666666666, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8333333333333334, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]')]
